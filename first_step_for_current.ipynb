# %% [markdown]
# <a href="https://colab.research.google.com/github/phule1812/iurc2/blob/master/first_step_for_current.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive
# drive.mount('/content/drive')
import warnings
warnings.filterwarnings('ignore')

# %%
import requests
import zipfile
from pathlib import Path

# Setup path to a data folder
data_path = Path("data/")
image_path = data_path/ 'dataset'

if image_path.is_dir():
  print(f'{image_path} directory already exists ... ')
else:
  print(f'{image_path} does not exist, creatin one ...')
  image_path.mkdir(parents = True, exist_ok = True)

# Download dataset
with open(data_path / 'dataset.zip', 'wb') as f:
  request = requests.get('https://github.com/phule1812/iurc2/raw/master/dataset.zip')
  print('Downloading dataset ...')
  f.write(request.content)

# Unzip dataset
with zipfile.ZipFile(data_path / "dataset.zip", 'r') as zip_ref:
  print('Unzipping dataset ...')
  zip_ref.extractall(image_path)
# Out:
# data/dataset directory already exists ...
# Downloading dataset ...
# Unzipping dataset ...

# %%
df_velocity = pd.read_csv('data/dataset/dataset/velocity.csv')
df_current = pd.read_csv('data/dataset/dataset/current.csv')
df_velocity = df_velocity.drop(columns = 'Unnamed: 0')
df_current = df_current.drop(columns = 'Unnamed: 0')

# %%
df = pd.concat([df_velocity, df_current], axis = 1)

# %%
df.head()
# Out:
#    w3*  w1*  w2*          w3          w1          w2  red_of_first_wheel  \
# 0  200  200  200  144.692308  158.000000  141.967742                   1
# 1  200  200  225  147.673469  157.950000  157.680000                   1
# 2  200  200  250  143.500000  162.000000  181.465116                   1
# 3  200  200  275  145.800000  168.000000  205.434783                   1
# 4  200  200  300  150.362069  164.213115  221.282609                   1
#
#    red_of_second_wheel  red_of_third_wheel  blue_of_first_wheel  \
# 0                    0                   0                    0
# 1                    0                   0                    0
# 2                    0                   0                    0
# 3                    0                   0                    0
# 4                    0                   0                    0
#
#    blue_of_second_wheel  blue_of_third_wheel  green_of_first_wheel  \
# 0                     1                    0                     0
# 1                     1                    0                     0
# 2                     1                    0                     0
# 3                     1                    0                     0
# 4                     1                    0                     0
#
#    green_of_second_wheel  green_of_third_wheel        I3        I1        I2
# 0                      0                     1  0.664165  0.488095  0.709957
# 1                      0                     1  0.653846  0.425032  0.857287
# 2                      0                     1  0.647837  0.394962  0.970985
# 3                      0                     1  0.561859  0.400314  0.995885
# 4                      0                     1  0.562024  0.392505  1.105096

# %% [markdown]
# ### Prediction of I:

# %%
X = df[['w1*', 'w2*', 'w3*', 'red_of_first_wheel', 'red_of_second_wheel', 'red_of_third_wheel', 'blue_of_first_wheel', 'blue_of_second_wheel', 'blue_of_third_wheel', 'green_of_first_wheel', 'green_of_second_wheel', 'green_of_third_wheel']]

# %%
# y = df[['w1', 'w2', 'w3']]
y = df[['I3']]

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 40)

# %%
def prediction_of_I3(model, X_train, y_train, X_test, y_test):
  #create pipeline of model
  pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('regression', model)
  ])

  # fit model
  pipeline.fit(X_train, y_train)
  y_pred = pipeline.predict(X_test)
  error = mean_squared_error(y_pred, y_test)
  print(f'Error of {model} : {error}')

  # plot real vs predicted values
  y_pred = pd.DataFrame(y_pred, columns = ['I3_pred'])
  df_concat = pd.concat([y_test.reset_index(), y_pred], axis = 1)

  df_concat['I3'].plot(kind='line', figsize=(8, 4), label='I3')
  df_concat['I3_pred'].plot(kind='line', figsize=(8, 4), label='I3_pred')
  plt.legend()
  plt.title(f'Real I3 vs predicted I3 with {model}')
  plt.show()

  return error

# %%
#Linear Regression model
linear_regression_error = prediction_of_I3(LinearRegression(), X_train, y_train, X_test, y_test)
# Out:
# Error of LinearRegression() : 0.0023881714925908957

# %%
# DecisionTree Regressor model
decision_tree_regressor_error = prediction_of_I3(DecisionTreeRegressor(), X_train, y_train, X_test, y_test)
# Out:
# Error of DecisionTreeRegressor() : 0.0030440488850853615

# %%
from sklearn.ensemble import RandomForestRegressor

# Random Forest Regressor model
random_forest_regressor_error = prediction_of_I3(RandomForestRegressor(), X_train, y_train, X_test, y_test)
# Out:
# Error of RandomForestRegressor() : 0.0024005748067725536

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Gradient Boosting Regression model
gradient_boosting_regression_error = prediction_of_I3(GradientBoostingRegressor(), X_train, y_train, X_test, y_test)
# Out:
# Error of GradientBoostingRegressor() : 0.0026467110268284856

# %%
from sklearn.svm import SVR

# Super Vector Regressor

super_vector_regressor_error = prediction_of_I3(SVR(), X_train, y_train, X_test, y_test)
# Out:
# Error of SVR() : 0.0025161001668180688

# %%
from sklearn.neighbors import KNeighborsRegressor

# K-Nearest Neighbors Regression

k_nearest_neightbors_regressor_error = prediction_of_I3(KNeighborsRegressor(), X_train, y_train, X_test, y_test)
# Out:
# Error of KNeighborsRegressor() : 0.001631206398809542

# %%
df_error = pd.DataFrame({
    'Linear_Regression' : [linear_regression_error],
    'Decision_Tree_Regressor' : [decision_tree_regressor_error],
    'Random Forest Regressor' : [random_forest_regressor_error],
    'Gradient Boosting Regression' : [gradient_boosting_regression_error],
    'Super Vector Regressor' : [super_vector_regressor_error],
    'K-Nearest Neighbors Regression' : [k_nearest_neightbors_regressor_error]
})

# %%
df_error = df_error.T
df_error
# Out:
#                                        0
# Linear_Regression               0.002388
# Decision_Tree_Regressor         0.003044
# Random Forest Regressor         0.002401
# Gradient Boosting Regression    0.002647
# Super Vector Regressor          0.002516
# K-Nearest Neighbors Regression  0.001631

# %%
df_3d = df[['w1*', 'w2*', 'I3']]

# %%
df_3d_plus = df_3d[(df_3d['w1*'] > 0) & (df_3d['w2*'] > 0)]

# %%
ax = plt.figure().add_subplot(projection='3d')

# Prepare arrays x, y, z
z = df_3d_plus['I3']
x = df_3d_plus['w1*']
y = df_3d_plus['w2*']

ax.scatter(x, y, z, label='I', c='r', marker='o')
ax.legend()
# Đặt tên cho các trục
ax.set_xlabel('w1*')
ax.set_ylabel('w2*')
ax.set_zlabel('I3')
plt.show()

# %%
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from scipy.spatial import Delaunay
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')
points = df_3d_plus.to_numpy()
tri = Delaunay(points)
ax.scatter(points[:, 0], points[:, 1], points[:, 2], c='b', marker='o', label='Points')
for simplex in tri.simplices:
    vertices = points[simplex]
    ax.add_collection3d(Poly3DCollection([vertices], facecolors='cyan', linewidths=1, edgecolors='r', alpha=0.5))

ax.set_xlabel('w2*')
ax.set_ylabel('w3')
ax.set_zlabel('I1')
ax.set_title('I3 от w1* и w2* (положительные значения)')
plt.show()

# %%
import pandas as pd
import plotly.graph_objects as go
from scipy.spatial import Delaunay

fig = go.Figure()

points = df_3d_plus.to_numpy()
tri = Delaunay(points)

fig.add_trace(go.Scatter3d(x=points[:, 0], y=points[:, 1], z=points[:, 2], mode='markers', marker=dict(color='blue'), name='Points'))

for simplex in tri.simplices:
    vertices = points[simplex]
    fig.add_trace(go.Mesh3d(x=vertices[:, 0], y=vertices[:, 1], z=vertices[:, 2], color='cyan', opacity=0.5))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0497598e-3ad3-4faf-a373-27f8579189e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0497598e-3ad3-4faf-a373-27f8579189e8")) {                    Plotly.newPlot(                        "0497598e-3ad3-4faf-a373-27f8579189e8",                        [{"marker":{"color":"blue"},"mode":"markers","name":"Points","x":[200.0,200.0,200.0,200.0,200.0,225.0,225.0,225.0,225.0,225.0,250.0,250.0,250.0,250.0,250.0,275.0,275.0,275.0,275.0,275.0,300.0,300.0,300.0,300.0,300.0],"y":[200.0,225.0,250.0,275.0,300.0,200.0,225.0,250.0,275.0,300.0,200.0,225.0,250.0,275.0,300.0,200.0,225.0,250.0,275.0,300.0,200.0,225.0,250.0,275.0,300.0],"z":[0.6641654390243901,0.6538464318181817,0.6478368749999999,0.5618591000000001,0.5620237432432434,0.6808024102564098,0.6520149610389606,0.5495496756756758,0.5143112441860466,0.478740582278481,0.6018101647058824,0.5933552957746483,0.5330801851851849,0.5223443428571427,0.4855143896103898,0.5715251184210527,0.551282161764706,0.5614036315789475,0.553520634920635,0.4958713220338983,0.5787547922077922,0.5870912586206898,0.4762392133333333,0.5101809705882353,0.4871793076923079],"type":"scatter3d"},{"color":"cyan","opacity":0.5,"x":[250.0,225.0,225.0,200.0],"y":[200.0,250.0,225.0,200.0],"z":[0.6018101647058824,0.5495496756756758,0.6520149610389606,0.6641654390243901],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[250.0,225.0,225.0,200.0],"y":[200.0,200.0,225.0,200.0],"z":[0.6018101647058824,0.6808024102564098,0.6520149610389606,0.6641654390243901],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[200.0,225.0,225.0,200.0],"y":[225.0,200.0,225.0,200.0],"z":[0.6538464318181817,0.6808024102564098,0.6520149610389606,0.6641654390243901],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[200.0,225.0,225.0,200.0],"y":[225.0,250.0,225.0,200.0],"z":[0.6538464318181817,0.5495496756756758,0.6520149610389606,0.6641654390243901],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[200.0,200.0,225.0,200.0],"y":[225.0,275.0,250.0,200.0],"z":[0.6538464318181817,0.5618591000000001,0.5495496756756758,0.6641654390243901],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[275.0,275.0,300.0,200.0],"y":[300.0,275.0,300.0,300.0],"z":[0.4958713220338983,0.553520634920635,0.4871793076923079,0.5620237432432434],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[200.0,275.0,225.0,225.0],"y":[250.0,275.0,200.0,225.0],"z":[0.6478368749999999,0.553520634920635,0.6808024102564098,0.6520149610389606],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[200.0,200.0,225.0,225.0],"y":[250.0,225.0,200.0,225.0],"z":[0.6478368749999999,0.6538464318181817,0.6808024102564098,0.6520149610389606],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[200.0,200.0,225.0,200.0],"y":[250.0,225.0,200.0,200.0],"z":[0.6478368749999999,0.6538464318181817,0.6808024102564098,0.6641654390243901],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[200.0,200.0,225.0,225.0],"y":[250.0,225.0,250.0,225.0],"z":[0.6478368749999999,0.6538464318181817,0.5495496756756758,0.6520149610389606],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[200.0,200.0,200.0,225.0],"y":[250.0,225.0,275.0,250.0],"z":[0.6478368749999999,0.6538464318181817,0.5618591000000001,0.5495496756756758],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[250.0,300.0,275.0,225.0],"y":[250.0,250.0,200.0,250.0],"z":[0.5330801851851849,0.4762392133333333,0.5715251184210527,0.5495496756756758],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[250.0,250.0,275.0,225.0],"y":[250.0,200.0,200.0,250.0],"z":[0.5330801851851849,0.6018101647058824,0.5715251184210527,0.5495496756756758],"type":"mesh3d"},{"color":"cyan","opacity":0.5,"x":[300.0,275.0,275.0,300.0],"y":[275.0,300.0,275.0,300.0],"z":[0.51018097058823 ...

# %%
df_3d_minus = df_3d[(df_3d['w1*'] < 0) & (df_3d['w2*'] < 0)]

# %%
ax = plt.figure().add_subplot(projection='3d')

# Prepare arrays x, y, z
z = df_3d_minus['I3']
x = df_3d_minus['w1*']
y = df_3d_minus['w2*']

ax.scatter(x, y, z, label='I', c='r', marker='o')
ax.legend()
# Đặt tên cho các trục
ax.set_xlabel('w1*')
ax.set_ylabel('w2*')
ax.set_zlabel('I3')
plt.show()

# %%
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from scipy.spatial import Delaunay
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')
points = df_3d_minus.to_numpy()
tri = Delaunay(points)
ax.scatter(points[:, 0], points[:, 1], points[:, 2], c='b', marker='o', label='Points')
for simplex in tri.simplices:
    vertices = points[simplex]
    ax.add_collection3d(Poly3DCollection([vertices], facecolors='cyan', linewidths=1, edgecolors='r', alpha=0.5))

ax.set_xlabel('w2*')
ax.set_ylabel('w3')
ax.set_zlabel('I1')
ax.set_title('I3 от w1* и w2* (отрицательные значения)')
plt.show()

# %%
import pandas as pd
import plotly.graph_objects as go
from scipy.spatial import Delaunay

fig = go.Figure()

points = df_3d_minus.to_numpy()
tri = Delaunay(points)

fig.add_trace(go.Scatter3d(x=points[:, 0], y=points[:, 1], z=points[:, 2], mode='markers', marker=dict(color='blue'), name='Points'))

for simplex in tri.simplices:
    vertices = points[simplex]
    fig.add_trace(go.Mesh3d(x=vertices[:, 0], y=vertices[:, 1], z=vertices[:, 2], color='cyan', opacity=0.5))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bb0435c7-bb18-41a1-9f8e-d0b590a2e61d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb0435c7-bb18-41a1-9f8e-d0b590a2e61d")) {                    Plotly.newPlot(                        "bb0435c7-bb18-41a1-9f8e-d0b590a2e61d",                        [{"marker":{"color":"blue"},"mode":"markers","name":"Points","x":[-200.0,-200.0,-200.0,-200.0,-200.0,-225.0,-225.0,-225.0,-225.0,-225.0,-250.0,-250.0,-250.0,-250.0,-250.0,-275.0,-275.0,-275.0,-275.0,-275.0,-300.0,-300.0,-300.0,-300.0,-300.0],"y":[-200.0,-225.0,-250.0,-275.0,-300.0,-200.0,-225.0,-250.0,-275.0,-